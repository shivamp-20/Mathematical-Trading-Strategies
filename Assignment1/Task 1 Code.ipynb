# %%
import yfinance as yf
import numpy as np
import pandas as pd
import math

ticker1="AAPL"
ticker2="HPQ"
ticker3="GOOGL"
ticker4="MSFT"
ticker5="BA"
Ticker1="^GSPC"
Ticker2="^DJI"
Ticker3="^IXIC"
Ticker4="^N225"
Ticker5="^FTSE"
data1 = yf.download(ticker1, start="2010-01-01", end="2023-05-01")
data2 = yf.download(ticker2, start="2010-01-01", end="2023-05-01")
data3 = yf.download(ticker3, start="2010-01-01", end="2023-05-01")
data4 = yf.download(ticker4, start="2010-01-01", end="2023-05-01")
data5 = yf.download(ticker5, start="2010-01-01", end="2023-05-01")
Data1 = yf.download(Ticker1, start="2010-01-01", end="2023-05-01")
Data2 = yf.download(Ticker2, start="2010-01-01", end="2023-05-01")
Data3 = yf.download(Ticker3, start="2010-01-01", end="2023-05-01")
Data4 = yf.download(Ticker4, start="2010-01-01", end="2023-05-01")
Data5 = yf.download(Ticker5, start="2010-01-01", end="2023-05-01")

data1['Daily Returns']=((data1['Close']-data1['Open'])/(data1['Open']))*100
# Here I have calculated the volatility(std) for all the days
dr1=(data1['Daily Returns'].std())*((252)**0.5)
print(str(dr1)+ " %")
data2['Daily Returns']=((data2['Close']-data2['Open'])/(data2['Open']))*100
# Here I have calculated the volatility(std) for all the days
dr2=(data2['Daily Returns'].std())*((252)**0.5)
print(str(dr2)+ " %")
data3['Daily Returns']=((data3['Close']-data3['Open'])/(data3["Open"]))*100
# Here I have calculated the volatility(std) for all the days
dr3=(data3['Daily Returns'].std())*((252)**0.5)
print(str(dr3)+ " %")
data4['Daily Returns']=((data4['Close']-data4['Open'])/(data4['Open']))*100
# Here I have calculated the volatility(std) for all the days
dr4=(data4['Daily Returns'].std())*((252)**0.5)
print(str(dr4)+" %")
data5['Daily Returns']=((data5['Close']-data5['Open'])/(data5['Open']))*100
# Here I have calculated the volatility(std) for all the days
dr5=(data5['Daily Returns'].std())*((252)**0.5)
print(str(dr5)+" %")

data1['Daily']=data1['Close']-data1['Open']
data2['Daily']=data2['Close']-data2['Open']
data3['Daily']=data3['Close']-data3['Open']
data4['Daily']=data4['Close']-data4['Open']
data5['Daily']=data5['Close']-data5['Open']

# Cumilative Returns
cr1=((data1.iloc[3352,3] - data1.iloc[0,3])/(data1.iloc[0,3]))*100
cr2=((data2.iloc[3352,3] - data2.iloc[0,3])/(data2.iloc[0,3]))*100
cr3=((data3.iloc[3352,3] - data3.iloc[0,3])/(data3.iloc[0,3]))*100
cr4=((data4.iloc[3352,3] - data4.iloc[0,3])/(data4.iloc[0,3]))*100
cr5=((data5.iloc[3352,3] - data5.iloc[0,3])/(data5.iloc[0,3]))*100
print(str(cr1)+" %")
print(str(cr2)+" %")
print(str(cr3)+" %")
print(str(cr4)+" %")
print(str(cr5)+" %")

# To calculate sharpe ratio, we have taken US treasury bond rate as 5.25
sr1=(((((data1['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data1['Daily Returns'].std()*pow(252,0.5))
sr2=(((((data2['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data2['Daily Returns'].std()*pow(252,0.5))
sr3=(((((data3['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data3['Daily Returns'].std()*pow(252,0.5))
sr4=(((((data4['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data4['Daily Returns'].std()*pow(252,0.5))
sr5=(((((data5['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data5['Daily Returns'].std()*pow(252,0.5))
print(sr1)
print(sr2)
print(sr3)
print(sr4)
print(sr5)


data1['Neg']=data1['Daily Returns']
data2['Neg']=data2['Daily Returns']
data3['Neg']=data3['Daily Returns']
data4['Neg']=data4['Daily Returns']
data5['Neg']=data5['Daily Returns']
# The daily US treasury bond rate from annual bond rate will be 0.02132
for i in range(3353):
 if(data1.iloc[i,8] - 0.02132 > 0):
        data1.iloc[i,8]=0
 else:
    data1.iloc[i,8]=data1.iloc[i,8]-0.02132
    
for i in range(3353):
 if(data2.iloc[i,8] - 0.02132 > 0):
        data2.iloc[i,8]=0
 else:
    data2.iloc[i,8]=data2.iloc[i,8]-0.02132  
    
for i in range(3353):
 if(data3.iloc[i,8] - 0.02132 > 0):
        data3.iloc[i,8]=0
 else:
    data3.iloc[i,8]=data3.iloc[i,8]-0.02132  
    
for i in range(3353):
 if(data4.iloc[i,8] - 0.02132 > 0):
        data4.iloc[i,8]=0
 else:
    data4.iloc[i,8]=data4.iloc[i,8]-0.02132
    
for i in range(3353):
 if(data5.iloc[i,8] - 0.02132 > 0):
        data5.iloc[i,8]=0
 else:
    data5.iloc[i,8]=data5.iloc[i,8]-0.02132  
    
    
# To calculate Sortiono Ratio
st1=(((((data1['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data1['Neg'].std()*pow(252,0.5))
st2=(((((data2['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data2['Neg'].std()*pow(252,0.5))
st3=(((((data3['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data3['Neg'].std()*pow(252,0.5))
st4=(((((data4['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data4['Neg'].std()*pow(252,0.5))
st5=(((((data5['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(data5['Neg'].std()*pow(252,0.5))
print(st1)
print(st2)
print(st3)
print(st4)
print(st5)

# Maximum Drawdown
# For Stock 1
x=0
max1=0
for i in range(3353):
    for j in range(i+1,3353):
        if(data1.iloc[i,3]>data1.iloc[j,3] and (data1.iloc[i,3]-data1.iloc[j,3])>max1):
            max1=data1.iloc[i,3]-data1.iloc[j,3]
            x=i        
        elif(data1.iloc[i,3]<=data1.iloc[j,3]):
            i=j
            break
            
print((-max1/data1.iloc[x,3])*100)            
# For Stock 2  
max1=0
x=0
for i in range(3353):
    for j in range(i+1,3353):
        if(data2.iloc[i,3]>data2.iloc[j,3] and (data2.iloc[i,3]-data2.iloc[j,3])>max1):
            max1=data2.iloc[i,3]-data2.iloc[j,3]
            x=i        
        elif(data2.iloc[i,3]<=data2.iloc[j,3]):
            i=j
            break
            
print((-max1/data2.iloc[x,3])*100)    
#For Stock 3
max1=0
x=0
for i in range(3353):
    for j in range(i+1,3353):
        if(data3.iloc[i,3]>data3.iloc[j,3] and (data3.iloc[i,3]-data3.iloc[j,3])>max1):
            max1=data3.iloc[i,3]-data3.iloc[j,3]
            x=i        
        elif(data3.iloc[i,3]<=data3.iloc[j,3]):
            i=j
            break
            
print((-max1/data3.iloc[x,3])*100)    
# For Stock 4
max1=0
x=0
for i in range(3353):
    for j in range(i+1,3353):
        if(data4.iloc[i,3]>data4.iloc[j,3] and (data4.iloc[i,3]-data4.iloc[j,3])>max1):
            max1=data4.iloc[i,3]-data4.iloc[j,3]
            x=i        
        elif(data4.iloc[i,3]<=data4.iloc[j,3]):
            i=j
            break
            
print((-max1/data4.iloc[x,3])*100)    
#For Stock 5
max1=0
x=0
for i in range(3353):
    for j in range(i+1,3353):
        if(data5.iloc[i,3]>data5.iloc[j,3] and (data5.iloc[i,3]-data5.iloc[j,3])>max1):
            max1=data5.iloc[i,3]-data5.iloc[j,3]
            x=i        
        elif(data5.iloc[i,3]<=data5.iloc[j,3]):
            i=j
            break
            
print((-max1/data5.iloc[x,3])*100)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# 22.24384688314914 %
# 26.297455545713618 %
# 20.50625531209582 %
# 20.077485127292093 %
# 26.958685349085393 %
# 2120.0083324068864 %
# 24.731013000324307 %
# 584.3727785685321 %
# 892.7625272744684 %
# 268.0669235600672 %
# 0.3970989002737325
# 1.0176584498643932
# -0.1375999499103953
# 0.5809341007664747
# -0.19881803527621067
# 0.6566417714163133
# 1.7159197138197853
# -0.21999635838234863
# 0.9585819523360644
# -0.3106674895784537
# -31.311466174254015
# -78.52164265505093
# -44.32005141440532
# -37.5564661050386
# -78.4372014005035

# %%
# For indices
Data1['Daily Returns']=((Data1['Close']-Data1['Open'])/(Data1['Open']))*100
# Here I have calculated the volatility(std) for all the days
Dr1=Data1['Daily Returns'].std()*pow(252,0.5)
print(str(Dr1)+ " %")
Data2['Daily Returns']=((Data2['Close']-Data2['Open'])/(Data2['Open']))*100
# Here I have calculated the volatility(std) for all the days
Dr2=Data2['Daily Returns'].std()*pow(252,0.5)
print(str(Dr2)+ " %")
Data3['Daily Returns']=((Data3['Close']-Data3['Open'])/(Data3["Open"]))*100
# Here I have calculated the volatility(std) for all the days
Dr3=Data3['Daily Returns'].std()*pow(252,0.5)
print(str(Dr3)+ " %")
Data4['Daily Returns']=((Data4['Close']-Data4['Open'])/(Data4['Open']))*100
# Here I have calculated the volatility(std) for all the days
Dr4=Data4['Daily Returns'].std()*pow(252,0.5)
print(str(Dr4)+" %")
Data5['Daily Returns']=((Data5['Close']-Data5['Open'])/(Data5['Open']))*100
# Here I have calculated the volatility(std) for all the days
Dr5=Data5['Daily Returns'].std()*pow(252,0.5)
print(str(Dr5)+" %")

Data1['Daily']=Data1['Close']-Data1['Open']
Data2['Daily']=Data2['Close']-Data2['Open']
Data3['Daily']=Data3['Close']-Data3['Open']
Data4['Daily']=Data4['Close']-Data4['Open']
Data5['Daily']=Data5['Close']-Data5['Open']


# Cumulative Retun
Cr1=((Data1.iloc[3351,3] - Data1.iloc[0,3])/(Data1.iloc[0,3]))*100
Cr2=((Data2.iloc[3352,3] - Data2.iloc[0,3])/(Data2.iloc[0,3]))*100
Cr3=((Data3.iloc[3352,3] - Data3.iloc[0,3])/(Data3.iloc[0,3]))*100
Cr4=((Data4.iloc[3258,3] - Data4.iloc[0,3])/(Data4.iloc[0,3]))*100
Cr5=((Data5.iloc[3352,3] - Data5.iloc[0,3])/(Data5.iloc[0,3]))*100
print(str(Cr1)+" %")
print(str(Cr2)+" %")
print(str(Cr3)+" %")
print(str(Cr4)+" %")
print(str(Cr5)+" %")


# To calculate sharpe ratio, we have taken the average of 10 years US treasury bond rate as 5.25
Sr1=(((((Data1['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data1['Daily Returns'].std()*pow(252,0.5))
Sr2=(((((Data2['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data2['Daily Returns'].std()*pow(252,0.5))
Sr3=(((((Data3['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data3['Daily Returns'].std()*pow(252,0.5))
Sr4=(((((Data4['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data4['Daily Returns'].std()*pow(252,0.5))
Sr5=(((((Data5['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data5['Daily Returns'].std()*pow(252,0.5))
print(Sr1)
print(Sr2)
print(Sr3)
print(Sr4)
print(Sr5)


Data1['Neg']=Data1['Daily Returns']
Data2['Neg']=Data2['Daily Returns']
Data3['Neg']=Data3['Daily Returns']
Data4['Neg']=Data4['Daily Returns']
Data5['Neg']=Data5['Daily Returns']

for i in range(3351):
 if(Data1.iloc[i,8] - 0.02132 > 0):
        Data1.iloc[i,8]=0
 else:
    Data1.iloc[i,8]=Data1.iloc[i,8]-0.02132
    
for i in range(3353):
 if(Data2.iloc[i,8] - 0.02132 > 0):
        Data2.iloc[i,8]=0
 else:
    Data2.iloc[i,8]=Data2.iloc[i,8]-0.02132   
    
for i in range(3353):
 if(Data3.iloc[i,8] - 0.02132 > 0):
        Data3.iloc[i,8]=0
 else:
    Data3.iloc[i,8]=Data3.iloc[i,8]-0.02132   
    
for i in range(3259):
 if(Data4.iloc[i,8] - 0.02132 > 0):
        Data4.iloc[i,8]=0
 else:
    Data4.iloc[i,8]=Data4.iloc[i,8]-0.02132
    
for i in range(3353):
 if(Data5.iloc[i,8] - 0.02132 > 0):
        Data5.iloc[i,8]=0
 else:
    Data5.iloc[i,8]=Data5.iloc[i,8]-0.02132    
    
    
    
# To calculate Sortiono Ratio
St1=(((((Data1['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data1['Neg'].std()*pow(252,0.5))
St2=(((((Data2['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data2['Neg'].std()*pow(252,0.5))
St3=(((((Data3['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data3['Neg'].std()*pow(252,0.5))
St4=(((((Data4['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data4['Neg'].std()*pow(252,0.5))
St5=(((((Data5['Daily Returns'].mean()/100)+1)**365)-1)*100-5.52)/(Data5['Neg'].std()*pow(252,0.5))
print(St1)
print(St2)
print(St3)
print(St4)
print(St5)


# Maximum Drawdown
# For Indice 1
x=0
max1=0
for i in range(3351):
    for j in range(i+1,3351):
        if(Data1.iloc[i,3]>Data1.iloc[j,3] and (Data1.iloc[i,3]-Data1.iloc[j,3])>max1):
            max1=Data1.iloc[i,3]-Data1.iloc[j,3]
            x=i        
        elif(Data1.iloc[i,3]<=Data1.iloc[j,3]):
            i=j
            break
            
print((-max1/Data1.iloc[x,3])*100)   
# For Indice 2  
max1=0
x=0
for i in range(3353):
    for j in range(i+1,3353):
        if(Data2.iloc[i,3]>Data2.iloc[j,3] and (Data2.iloc[i,3]-Data2.iloc[j,3])>max1):
            max1=Data2.iloc[i,3]-Data2.iloc[j,3]
            x=i        
        elif(Data2.iloc[i,3]<=Data2.iloc[j,3]):
            i=j
            break
            
print((-max1/Data2.iloc[x,3])*100)  
#For Indice 3
max1=0
x=0
for i in range(3353):
    for j in range(i+1,3353):
        if(Data3.iloc[i,3]>Data3.iloc[j,3] and (Data3.iloc[i,3]-Data3.iloc[j,3])>max1):
            max1=Data3.iloc[i,3]-Data3.iloc[j,3]
            x=i        
        elif(Data3.iloc[i,3]<=Data3.iloc[j,3]):
            i=j
            break
            
print((-max1/Data3.iloc[x,3])*100)  
# For Indice 4
max1=0
x=0
for i in range(3259):
    for j in range(i+1,3259):
        if(Data4.iloc[i,3]>Data4.iloc[j,3] and (Data4.iloc[i,3]-Data4.iloc[j,3])>max1):
            max1=Data4.iloc[i,3]-Data4.iloc[j,3]
            x=i        
        elif(Data4.iloc[i,3]<=Data4.iloc[j,3]):
            i=j
            break
            
print((-max1/Data4.iloc[x,3])*100)
#For Indice 5
max1=0
x=0
for i in range(3353):
    for j in range(i+1,3353):
        if(Data5.iloc[i,3]>Data5.iloc[j,3] and (Data5.iloc[i,3]-Data5.iloc[j,3])>max1):
            max1=Data5.iloc[i,3]-Data5.iloc[j,3]
            x=i        
        elif(Data5.iloc[i,3]<=Data5.iloc[j,3]):
            i=j
            break
            
print((-max1/Data5.iloc[x,3])*100)
# Out:
# 14.865684203963376 %
# 14.489920173894719 %
# 16.034357851986737 %
# 14.49367984446237 %
# 16.252416946145253 %
# 268.0067799721897 %
# 222.16826482806985 %
# 429.65147121906807 %
# 170.83067190748733 %
# 43.117651434838336 %
# 0.3603854294821681
# 0.4051937465774901
# 0.2613562991569857
# -0.598418617157324
# 0.03290981288567929
# 0.5545600581526042
# 0.6299156552443944
# 0.406530636927068
# -0.8999047716003568
# 0.05077755495692547
# -25.4250966192304
# -37.086171369594325
# -36.395279909120205
# -31.79889650850191
# -36.60552329617582

# %%
data1
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-