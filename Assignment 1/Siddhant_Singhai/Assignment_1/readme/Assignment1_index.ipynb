# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import datetime
import plotly.express as px
import plotly.graph_objs as go

# %%
tickers = ['VFIAX','JNK','DIA','SCHA','NASDX']

# %%
df = pd.DataFrame()
for ticker in tickers:
    df_tmp=yf.download(ticker, start='2010-1-1', end='2023-5-10')
    df_tmp['Ticker'] = ticker
    df = pd.concat([df, df_tmp])
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00  104.320000  104.320000  104.320000  104.320000
# 2010-01-05 00:00:00-05:00  104.650002  104.650002  104.650002  104.650002
# 2010-01-06 00:00:00-05:00  104.750000  104.750000  104.750000  104.750000
# 2010-01-07 00:00:00-05:00  105.180000  105.180000  105.180000  105.180000
# 2010-01-08 00:00:00-05:00  105.480003  105.480003  105.480003  105.480003
# ...                               ...         ...         ...         ...
# 2023-05-03 00:00:00-04:00   28.120001   28.120001   28.120001   28.120001
# 2023-05-04 00:00:00-04:00   28.020000   28.020000   28.020000   28.020000
# 2023-05-05 00:00:00-04:00   28.610001   28.610001   28.610001   28.610001
# 2023-05-08 00:00:00-04:00   28.680000   28.680000   28.680000   28.680000
# 2023-05-09 00:00:00-04:00   28.490000   28.490000   28.490000   28.490000
#
#                            Adj Close  Volume Ticker
# Date
# 2010-01-04 00:00:00-05:00  80.937805       0  VFIAX
# 2010-01-05 00:00:00-05:00  81.193840       0  VFIAX
# 2010-01-06 00:00:00-05:00  81.271408       0  VFIAX
# 2010-01-07 00:00:00-05:00  81.605042       0  VFIAX
# 2010-01-08 00:00:00-05:00  81.837791       0  VFIAX
# ...                              ...     ...    ...
# 2023-05-03 00:00:00-04:00  28.120001       0  NASDX
# 2023-05-04 00:00:00-04:00  28.020000       0  NASDX
# 2023-05-05 00:00:00-04:00  28.610001       0  NASDX
# 2023-05-08 00:00:00-04:00  28.680000       0  NASDX
# 2023-05-09 00:00:00-04:00  28.490000       0  NASDX
#
# [16800 rows x 7 columns]

# %%
df.reset_index(inplace=True)

# %%
df.groupby('Ticker')['Date'].agg(['min', 'max', 'count'])
# Out:
#                              min                       max  count
# Ticker
# DIA    2010-01-04 00:00:00-05:00 2023-05-09 00:00:00-04:00   3360
# JNK    2010-01-04 00:00:00-05:00 2023-05-09 00:00:00-04:00   3360
# NASDX  2010-01-04 00:00:00-05:00 2023-05-09 00:00:00-04:00   3360
# SCHA   2010-01-04 00:00:00-05:00 2023-05-09 00:00:00-04:00   3360
# VFIAX  2010-01-04 00:00:00-05:00 2023-05-09 00:00:00-04:00   3360

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# Ticker       0
# dtype: int64

# %%
df_mod = df[['Date', 'Ticker', 'Adj Close']]
# make columns names prettier
df_mod.columns = ['date', 'ticker', 'price']
df_mod
# Out:
#                            date ticker      price
# 0     2010-01-04 00:00:00-05:00  VFIAX  80.937805
# 1     2010-01-05 00:00:00-05:00  VFIAX  81.193840
# 2     2010-01-06 00:00:00-05:00  VFIAX  81.271408
# 3     2010-01-07 00:00:00-05:00  VFIAX  81.605042
# 4     2010-01-08 00:00:00-05:00  VFIAX  81.837791
# ...                         ...    ...        ...
# 16795 2023-05-03 00:00:00-04:00  NASDX  28.120001
# 16796 2023-05-04 00:00:00-04:00  NASDX  28.020000
# 16797 2023-05-05 00:00:00-04:00  NASDX  28.610001
# 16798 2023-05-08 00:00:00-04:00  NASDX  28.680000
# 16799 2023-05-09 00:00:00-04:00  NASDX  28.490000
#
# [16800 rows x 3 columns]

# %%
df1 = df_mod.pivot_table(index=['date'], columns='ticker', values=['price'])
# flatten columns multi-index, `date` will become the dataframe index
df1.columns = [col[1] for col in df1.columns.values]
df1_reuse=df1
df1
# Out:
#                                   DIA        JNK      NASDX       SCHA  \
# date
# 2010-01-04 00:00:00-05:00   78.535622  50.810059   3.731557  11.461826
# 2010-01-05 00:00:00-05:00   78.409241  51.288162   3.731557  11.495074
# 2010-01-06 00:00:00-05:00   78.461327  51.456158   3.715910  11.511699
# 2010-01-07 00:00:00-05:00   78.743698  51.624119   3.715910  11.598969
# 2010-01-08 00:00:00-05:00   78.870087  51.817997   3.747204  11.657149
# ...                               ...        ...        ...        ...
# 2023-05-03 00:00:00-04:00  334.109985  91.449997  28.120001  40.430000
# 2023-05-04 00:00:00-04:00  331.329987  91.180000  28.020000  39.910000
# 2023-05-05 00:00:00-04:00  336.730011  91.650002  28.610001  40.860001
# 2023-05-08 00:00:00-04:00  336.220001  91.470001  28.680000  40.779999
# 2023-05-09 00:00:00-04:00  335.769989  91.250000  28.490000  40.619999
#
#                                 VFIAX
# date
# 2010-01-04 00:00:00-05:00   80.937805
# 2010-01-05 00:00:00-05:00   81.193840
# 2010-01-06 00:00:00-05:00   81.271408
# 2010-01-07 00:00:00-05:00   81.605042
# 2010-01-08 00:00:00-05:00   81.837791
# ...                               ...
# 2023-05-03 00:00:00-04:00  377.709991
# 2023-05-04 00:00:00-04:00  375.019989
# 2023-05-05 00:00:00-04:00  381.970001
# 2023-05-08 00:00:00-04:00  382.149994
# 2023-05-09 00:00:00-04:00  380.429993
#
# [3360 rows x 5 columns]

# %% [markdown]
# Compute cumulative returns from prices

# %%
cum_return = (df1.iloc[-1] - df1.iloc[0]) / df1.iloc[0]
cum_return * 100
# Out:
# DIA      327.538462
# JNK       79.590425
# NASDX    663.488238
# SCHA     254.393774
# VFIAX    370.027562
# dtype: float64

# %% [markdown]
# Compute cumulative returns from simple daily returns

# %%
# compute daily returns using pandas pct_change()
df_daily_returns = df1.pct_change()
# skip first row with NA 
df_daily_returns = df_daily_returns[1:]
df_daily_returns
# Out:
#                                 DIA       JNK     NASDX      SCHA     VFIAX
# date
# 2010-01-05 00:00:00-05:00 -0.001609  0.009410  0.000000  0.002901  0.003163
# 2010-01-06 00:00:00-05:00  0.000664  0.003276 -0.004193  0.001446  0.000955
# 2010-01-07 00:00:00-05:00  0.003599  0.003264  0.000000  0.007581  0.004105
# 2010-01-08 00:00:00-05:00  0.001605  0.003756  0.008421  0.005016  0.002852
# 2010-01-11 00:00:00-05:00  0.004053 -0.000998 -0.004176 -0.001782  0.001801
# ...                             ...       ...       ...       ...       ...
# 2023-05-03 00:00:00-04:00 -0.008193 -0.001201 -0.006360  0.001238 -0.006967
# 2023-05-04 00:00:00-04:00 -0.008321 -0.002952 -0.003556 -0.012862 -0.007122
# 2023-05-05 00:00:00-04:00  0.016298  0.005155  0.021056  0.023804  0.018532
# 2023-05-08 00:00:00-04:00 -0.001515 -0.001964  0.002447 -0.001958  0.000471
# 2023-05-09 00:00:00-04:00 -0.001338 -0.002405 -0.006625 -0.003923 -0.004501
#
# [3359 rows x 5 columns]

# %%
# Calculate the cumulative daily returns
df_cum_daily_returns = (1 + df_daily_returns).cumprod() - 1
df_cum_daily_returns = df_cum_daily_returns.reset_index()
df_cum_daily_returns
# Out:
#                           date       DIA       JNK         NASDX      SCHA  \
# 0    2010-01-05 00:00:00-05:00 -0.001609  0.009410  0.000000e+00  0.002901
# 1    2010-01-06 00:00:00-05:00 -0.000946  0.012716 -4.193074e-03  0.004351
# 2    2010-01-07 00:00:00-05:00  0.002649  0.016022 -4.193074e-03  0.011965
# 3    2010-01-08 00:00:00-05:00  0.004259  0.019837  4.193010e-03  0.017041
# 4    2010-01-11 00:00:00-05:00  0.008329  0.018820  2.220446e-16  0.015229
# ...                        ...       ...       ...           ...       ...
# 3354 2023-05-03 00:00:00-04:00  3.254248  0.799840  6.535728e+00  2.527361
# 3355 2023-05-04 00:00:00-04:00  3.218850  0.794527  6.508930e+00  2.481993
# 3356 2023-05-05 00:00:00-04:00  3.287609  0.803777  6.667041e+00  2.564877
# 3357 2023-05-08 00:00:00-04:00  3.281115  0.800234  6.685800e+00  2.557897
# 3358 2023-05-09 00:00:00-04:00  3.275385  0.795904  6.634882e+00  2.543938
#
#          VFIAX
# 0     0.003163
# 1     0.004122
# 2     0.008244
# 3     0.011119
# 4     0.012941
# ...        ...
# 3354  3.666670
# 3355  3.633434
# 3356  3.719303
# 3357  3.721527
# 3358  3.700276
#
# [3359 rows x 6 columns]

# %%
cum_return_entire_period = df_cum_daily_returns.iloc[:, 1:].tail(1)
cum_return_entire_period * 100
# Out:
#              DIA        JNK       NASDX        SCHA       VFIAX
# 3358  327.538462  79.590425  663.488238  254.393774  370.027562

# %% [markdown]
# Visualize the returns

# %%
# reset the index, moving `date` as column
df_daily_returns = df_daily_returns.reset_index()
# use `melt`
df1 = df_daily_returns.melt(id_vars=['date'], var_name='ticker', value_name='daily_return')
# add one more column, showing the daily_return as percent
df1['daily_return_pct'] = df1['daily_return'] * 100
df1
# Out:
#                            date ticker  daily_return  daily_return_pct
# 0     2010-01-05 00:00:00-05:00    DIA     -0.001609         -0.160922
# 1     2010-01-06 00:00:00-05:00    DIA      0.000664          0.066428
# 2     2010-01-07 00:00:00-05:00    DIA      0.003599          0.359886
# 3     2010-01-08 00:00:00-05:00    DIA      0.001605          0.160506
# 4     2010-01-11 00:00:00-05:00    DIA      0.004053          0.405295
# ...                         ...    ...           ...               ...
# 16790 2023-05-03 00:00:00-04:00  VFIAX     -0.006967         -0.696707
# 16791 2023-05-04 00:00:00-04:00  VFIAX     -0.007122         -0.712187
# 16792 2023-05-05 00:00:00-04:00  VFIAX      0.018532          1.853238
# 16793 2023-05-08 00:00:00-04:00  VFIAX      0.000471          0.047122
# 16794 2023-05-09 00:00:00-04:00  VFIAX     -0.004501         -0.450085
#
# [16795 rows x 4 columns]

# %%
fig = px.line(df1, x='date',
              y='daily_return_pct', color='ticker',
              title='Performance - Daily Simple Returns',
              labels={'daily_return_pct':'daily returns (%)'})
fig.show()

# %%
df2 = df_cum_daily_returns.melt(id_vars=['date'], var_name='ticker', value_name='cum_return')
df2['cum_return_pct'] = df2['cum_return'] * 100
df2
# Out:
#                            date ticker  cum_return  cum_return_pct
# 0     2010-01-05 00:00:00-05:00    DIA   -0.001609       -0.160922
# 1     2010-01-06 00:00:00-05:00    DIA   -0.000946       -0.094600
# 2     2010-01-07 00:00:00-05:00    DIA    0.002649        0.264945
# 3     2010-01-08 00:00:00-05:00    DIA    0.004259        0.425877
# 4     2010-01-11 00:00:00-05:00    DIA    0.008329        0.832898
# ...                         ...    ...         ...             ...
# 16790 2023-05-03 00:00:00-04:00  VFIAX    3.666670      366.666956
# 16791 2023-05-04 00:00:00-04:00  VFIAX    3.633434      363.343413
# 16792 2023-05-05 00:00:00-04:00  VFIAX    3.719303      371.930268
# 16793 2023-05-08 00:00:00-04:00  VFIAX    3.721527      372.152652
# 16794 2023-05-09 00:00:00-04:00  VFIAX    3.700276      370.027562
#
# [16795 rows x 4 columns]

# %%
fig = px.line(df2, x='date',
              y='cum_return_pct', color='ticker',
              title='Performance - Daily Cumulative Returns',
              labels={'cum_return_pct':'daily cumulative returns (%)', })
fig.show()

# %%
df1_mod = df1[['date', 'ticker', 'daily_return']]
df1_mod
# Out:
#                            date ticker  daily_return
# 0     2010-01-05 00:00:00-05:00    DIA     -0.001609
# 1     2010-01-06 00:00:00-05:00    DIA      0.000664
# 2     2010-01-07 00:00:00-05:00    DIA      0.003599
# 3     2010-01-08 00:00:00-05:00    DIA      0.001605
# 4     2010-01-11 00:00:00-05:00    DIA      0.004053
# ...                         ...    ...           ...
# 16790 2023-05-03 00:00:00-04:00  VFIAX     -0.006967
# 16791 2023-05-04 00:00:00-04:00  VFIAX     -0.007122
# 16792 2023-05-05 00:00:00-04:00  VFIAX      0.018532
# 16793 2023-05-08 00:00:00-04:00  VFIAX      0.000471
# 16794 2023-05-09 00:00:00-04:00  VFIAX     -0.004501
#
# [16795 rows x 3 columns]

# %%
df3 = df1_mod.pivot_table(index=['date'], columns='ticker', values=['daily_return'])
# flatten columns multi-index, `date` will become the dataframe index
df3.columns = [col[1] for col in df3.columns.values]
df3
# Out:
#                                 DIA       JNK     NASDX      SCHA     VFIAX
# date
# 2010-01-05 00:00:00-05:00 -0.001609  0.009410  0.000000  0.002901  0.003163
# 2010-01-06 00:00:00-05:00  0.000664  0.003276 -0.004193  0.001446  0.000955
# 2010-01-07 00:00:00-05:00  0.003599  0.003264  0.000000  0.007581  0.004105
# 2010-01-08 00:00:00-05:00  0.001605  0.003756  0.008421  0.005016  0.002852
# 2010-01-11 00:00:00-05:00  0.004053 -0.000998 -0.004176 -0.001782  0.001801
# ...                             ...       ...       ...       ...       ...
# 2023-05-03 00:00:00-04:00 -0.008193 -0.001201 -0.006360  0.001238 -0.006967
# 2023-05-04 00:00:00-04:00 -0.008321 -0.002952 -0.003556 -0.012862 -0.007122
# 2023-05-05 00:00:00-04:00  0.016298  0.005155  0.021056  0.023804  0.018532
# 2023-05-08 00:00:00-04:00 -0.001515 -0.001964  0.002447 -0.001958  0.000471
# 2023-05-09 00:00:00-04:00 -0.001338 -0.002405 -0.006625 -0.003923 -0.004501
#
# [3359 rows x 5 columns]

# %% [markdown]
# the daily, monthly, and annually *Volatility* of a stock

# %%
import math
for column in df3.columns[0:]:
    daily_volatility = df3[column].std()
    print(column)
    print('Daily volatility: ', '{:.2f}%'.format(daily_volatility*100))
    monthly_volatility = math.sqrt(21) * daily_volatility *100
    print('Monthly volatility: ', '{:.2f}%'.format(monthly_volatility))
    annual_volatility = math.sqrt(252) * daily_volatility *100
    print('Annual volatility: ', '{:.2f}%'.format(annual_volatility))
# Out:
# DIA
# Daily volatility:  1.08%
# Monthly volatility:  4.93%
# Annual volatility:  17.09%
# JNK
# Daily volatility:  0.56%
# Monthly volatility:  2.55%
# Annual volatility:  8.82%
# NASDX
# Daily volatility:  1.32%
# Monthly volatility:  6.03%
# Annual volatility:  20.88%
# SCHA
# Daily volatility:  1.39%
# Monthly volatility:  6.35%
# Annual volatility:  22.00%
# VFIAX
# Daily volatility:  1.12%
# Monthly volatility:  5.13%
# Annual volatility:  17.76%

# %% [markdown]
# Sharpe Ratio

# %%
for column in df3.columns[0:]:
    daily_volatility = df3[column].std()
    # print(column)
    Sharpe_Ratio =(df3[column].mean()*252) / (df3[column].std()*np.sqrt(252))
    
    print(column + " : ", '{:.6f}'.format(Sharpe_Ratio))
# Out:
# DIA :  0.723840
# JNK :  0.542189
# NASDX :  0.835269
# SCHA :  0.542235
# VFIAX :  0.743102

# %% [markdown]
# Sortiono Ratio

# %%
for column in df3.columns[0:]:
    downside_returns = df3.loc[df3[column] < 0]
    expected_return = df3[column].mean()
    down_stdev = downside_returns[column].std()
    rfr=0
    sortino_ratio = (expected_return - rfr)/down_stdev
    sortino_ratio=sortino_ratio*np.sqrt(252)
    print(column + " : ", '{:.6f}'.format(sortino_ratio))
# Out:
# DIA :  0.868679
# JNK :  0.645181
# NASDX :  1.060506
# SCHA :  0.691324
# VFIAX :  0.908191

# %% [markdown]
# Max Drawdown

# %%
for column in df1_reuse.columns[0:]:
    Roll_Max = df1_reuse[column].cummax()
    Daily_Drawdown = df1_reuse[column]/Roll_Max - 1.0
    Max_Daily_Drawdown = Daily_Drawdown.cummin()
    k=Max_Daily_Drawdown.mean()*100
    print(column + " : ", '{:.6f}%'.format(k))
# Out:
# DIA :  -20.509603%
# JNK :  -15.249680%
# NASDX :  -19.520914%
# SCHA :  -30.258311%
# VFIAX :  -21.663097%
