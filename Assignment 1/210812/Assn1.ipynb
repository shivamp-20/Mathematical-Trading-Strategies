# %% [markdown]
# # Assignment-1 #

# %% [markdown]
# Calculate Daily Returns, Cumulative Returns, Max. Drawdown, Sharpe Ratio and Sortino Ratio for 5 international indices and 5 equities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
Equities = yf.download(tickers=["MSFT", "005930.KS", "PG", "NSRGF", "KO", "^STOXX50E", "^FTSE", "^N225", "^GDAXI", "^AXJO"], start="2010-01-01", end = "2023-05-01")
# Out:
# [*********************100%***********************]  10 of 10 completed

# %% [markdown]
# # Cumulative Return #

# %%
Equities.head()
# Out:
#                Adj Close                                              \
#                005930.KS         KO       MSFT      NSRGF         PG
# Date
# 2009-12-31           NaN  18.923088  23.214399  40.109692  40.596905
# 2010-01-04  12571.507812  18.936367  23.572369  40.686214  40.925007
# 2010-01-05  12773.524414  18.707298  23.579987  39.615520  40.938385
# 2010-01-06  13068.775391  18.700653  23.435274  39.409615  40.744221
# 2010-01-07  12633.666992  18.654175  23.191563  38.709557  40.523251
#
#                                                                               \
#                   ^AXJO        ^FTSE       ^GDAXI         ^N225    ^STOXX50E
# Date
# 2009-12-31          NaN  5412.899902          NaN           NaN  2966.239990
# 2010-01-04  4876.299805  5500.299805  6048.299805  10654.790039  3017.800049
# 2010-01-05  4924.299805  5522.500000  6031.859863  10681.830078  3012.360107
# 2010-01-06  4921.399902  5530.000000  6034.330078  10731.450195  3009.659912
# 2010-01-07  4899.399902  5526.700195  6019.359863  10681.660156  3007.340088
#
#             ...      Volume                                                    \
#             ...   005930.KS          KO        MSFT    NSRGF         PG ^AXJO
# Date        ...
# 2009-12-31  ...         NaN  10848800.0  31929700.0   1500.0  5942200.0   NaN
# 2010-01-04  ...  11950800.0  13870400.0  38409100.0   7800.0  9190800.0   0.0
# 2010-01-05  ...  27925850.0  23172400.0  49749600.0   3300.0  8649400.0   0.0
# 2010-01-06  ...  22948850.0  19264600.0  58182400.0  11700.0  9908400.0   0.0
# 2010-01-07  ...  22107950.0  13234600.0  50559700.0   4900.0  8972800.0   0.0
#
#
#                    ^FTSE       ^GDAXI        ^N225 ^STOXX50E
# Date
# 2009-12-31  1.738476e+08          NaN          NaN       0.0
# 2010-01-04  7.509420e+08  104344400.0  104400000.0       0.0
# 2010-01-05  1.149301e+09  117572100.0  166200000.0       0.0
# 2010-01-06  9.982953e+08  108742400.0  181800000.0       0.0
# 2010-01-07  1.162934e+09  133704300.0  182600000.0       0.0
#
# [5 rows x 60 columns]

# %%
Equities.dropna(inplace= True)

# %%
Equities.head()
# Out:
#                Adj Close                                              \
#                005930.KS         KO       MSFT      NSRGF         PG
# Date
# 2010-01-04  12571.507812  18.936367  23.572369  40.686214  40.925007
# 2010-01-05  12773.524414  18.707298  23.579987  39.615520  40.938385
# 2010-01-06  13068.775391  18.700653  23.435274  39.409615  40.744221
# 2010-01-07  12633.666992  18.654175  23.191563  38.709557  40.523251
# 2010-01-08  12757.980469  18.308914  23.351496  39.739067  40.469688
#
#                                                                               \
#                   ^AXJO        ^FTSE       ^GDAXI         ^N225    ^STOXX50E
# Date
# 2010-01-04  4876.299805  5500.299805  6048.299805  10654.790039  3017.800049
# 2010-01-05  4924.299805  5522.500000  6031.859863  10681.830078  3012.360107
# 2010-01-06  4921.399902  5530.000000  6034.330078  10731.450195  3009.659912
# 2010-01-07  4899.399902  5526.700195  6019.359863  10681.660156  3007.340088
# 2010-01-08  4912.100098  5534.200195  6037.609863  10798.320312  3017.850098
#
#             ...      Volume                                                    \
#             ...   005930.KS          KO        MSFT    NSRGF         PG ^AXJO
# Date        ...
# 2010-01-04  ...  11950800.0  13870400.0  38409100.0   7800.0  9190800.0   0.0
# 2010-01-05  ...  27925850.0  23172400.0  49749600.0   3300.0  8649400.0   0.0
# 2010-01-06  ...  22948850.0  19264600.0  58182400.0  11700.0  9908400.0   0.0
# 2010-01-07  ...  22107950.0  13234600.0  50559700.0   4900.0  8972800.0   0.0
# 2010-01-08  ...  14777550.0  28712400.0  51197400.0  11000.0  8464600.0   0.0
#
#
#                    ^FTSE       ^GDAXI        ^N225 ^STOXX50E
# Date
# 2010-01-04  7.509420e+08  104344400.0  104400000.0       0.0
# 2010-01-05  1.149301e+09  117572100.0  166200000.0       0.0
# 2010-01-06  9.982953e+08  108742400.0  181800000.0       0.0
# 2010-01-07  1.162934e+09  133704300.0  182600000.0       0.0
# 2010-01-08  1.006421e+09  126099000.0  211800000.0       0.0
#
# [5 rows x 60 columns]

# %%
Equi_Indi_list = list(dict.fromkeys(Equities.columns.get_level_values(1)))[:10]

# %%
Equities.dropna(inplace=True)
Equities.loc[:, "Adj Close"].head()
# Out:
#                005930.KS         KO       MSFT      NSRGF         PG  \
# Date
# 2010-01-04  12571.507812  18.936367  23.572369  40.686214  40.925007
# 2010-01-05  12773.524414  18.707298  23.579987  39.615520  40.938385
# 2010-01-06  13068.775391  18.700653  23.435274  39.409615  40.744221
# 2010-01-07  12633.666992  18.654175  23.191563  38.709557  40.523251
# 2010-01-08  12757.980469  18.308914  23.351496  39.739067  40.469688
#
#                   ^AXJO        ^FTSE       ^GDAXI         ^N225    ^STOXX50E
# Date
# 2010-01-04  4876.299805  5500.299805  6048.299805  10654.790039  3017.800049
# 2010-01-05  4924.299805  5522.500000  6031.859863  10681.830078  3012.360107
# 2010-01-06  4921.399902  5530.000000  6034.330078  10731.450195  3009.659912
# 2010-01-07  4899.399902  5526.700195  6019.359863  10681.660156  3007.340088
# 2010-01-08  4912.100098  5534.200195  6037.609863  10798.320312  3017.850098

# %%
for index in Equi_Indi_list:
    new_column = np.log(Equities.loc[:, ('Adj Close' ,index)].div(Equities.loc[:, ('Adj Close', index)].shift(1)))
    Equities.insert(loc=len(Equities.columns), column=('d_returns', index), value=new_column)
Equities.dropna(inplace=True)

# %%
for index in Equi_Indi_list:
    new_column = Equities.d_returns[index].cumsum().apply(np.exp)
    Equities.insert(loc=len(Equities.columns), column=('C_returns', index), value=new_column)

# %%
Equities.dropna(inplace=True)
Equities
# Out:
#                Adj Close                                                 \
#                005930.KS         KO        MSFT       NSRGF          PG
# Date
# 2010-01-05  12773.524414  18.707298   23.579987   39.615520   40.938385
# 2010-01-06  13068.775391  18.700653   23.435274   39.409615   40.744221
# 2010-01-07  12633.666992  18.654175   23.191563   38.709557   40.523251
# 2010-01-08  12757.980469  18.308914   23.351496   39.739067   40.469688
# 2010-01-12  12571.507812  18.883247   22.902140   39.739067   40.771004
# ...                  ...        ...         ...         ...         ...
# 2023-04-21  65700.000000  64.050003  285.136688  127.232994  156.070007
# 2023-04-24  65200.000000  63.950001  281.155365  129.199997  156.350006
# 2023-04-26  64100.000000  63.549999  294.725708  128.639999  154.580002
# 2023-04-27  64600.000000  63.680000  304.165070  127.180000  156.470001
# 2023-04-28  65500.000000  64.150002  306.589783  128.059998  156.380005
#
#                                                                                \
#                   ^AXJO        ^FTSE        ^GDAXI         ^N225    ^STOXX50E
# Date
# 2010-01-05  4924.299805  5522.500000   6031.859863  10681.830078  3012.360107
# 2010-01-06  4921.399902  5530.000000   6034.330078  10731.450195  3009.659912
# 2010-01-07  4899.399902  5526.700195   6019.359863  10681.660156  3007.340088
# 2010-01-08  4912.100098  5534.200195   6037.609863  10798.320312  3017.850098
# 2010-01-12  4899.500000  5498.700195   5943.000000  10879.139648  2976.889893
# ...                 ...          ...           ...           ...          ...
# 2023-04-21  7330.399902  7914.100098  15881.660156  28564.369141  4408.589844
# 2023-04-24  7322.000000  7912.200195  15863.950195  28593.519531  4401.799805
# 2023-04-26  7316.299805  7852.600098  15795.730469  28416.470703  4347.709961
# 2023-04-27  7292.700195  7831.600098  15800.450195  28457.679688  4358.049805
# 2023-04-28  7309.200195  7870.600098  15922.379883  28856.439453  4359.310059
#
#             ... C_returns                                                     \
#             ... 005930.KS        KO       MSFT     NSRGF        PG     ^AXJO
# Date        ...
# 2010-01-05  ...  1.016069  0.987903   1.000323  0.973684  1.000327  1.009844
# 2010-01-06  ...  1.039555  0.987552   0.994184  0.968623  0.995583  1.009249
# 2010-01-07  ...  1.004944  0.985098   0.983845  0.951417  0.990183  1.004737
# 2010-01-08  ...  1.014833  0.966865   0.990630  0.976721  0.988874  1.007342
# 2010-01-12  ...  1.000000  0.997195   0.971567  0.976721  0.996237  1.004758
# ...         ...       ...       ...        ...       ...       ...       ...
# 2023-04-21  ...  5.226103  3.382381  12.096226  3.127177  3.813561  1.503271
# 2023-04-24  ...  5.186331  3.377100  11.927328  3.175523  3.820403  1.501548
# 2023-04-26  ...  5.098831  3.355976  12.503016  3.161759  3.777153  1.500379
# 2023-04-27  ...  5.138604  3.362841  12.903458  3.125875  3.823335  1.495540
# 2023-04-28  ...  5.210194  3.387661  13.006321  3.147503  3.821136  1.498923
#
#
#                ^FTSE    ^GDAXI     ^N225 ^STOXX50E
# Date
# 2010-01-05  1.004036  0.997282  1.002538  0.998197
# 2010-01-06  1.005400  0.997690  1.007195  0.997303
# 2010-01-07  1.004800  0.995215  1.002522  0.996534
# 2010-01-08  1.006163  0.998233  1.013471  1.000017
# 2010-01-12  0.999709  0.982590  1.021056  0.986444
# ...              ...       ...       ...       ...
# 2023-04-21  1.438849  2.625806  2.680895  1.460862
# 2023-04-24  1.438503  2.622878  2.683631  1.458612
# 2023-04-26  1.427668  2.611598  2.667014  1.440689
# 2023-04-27  1.423850  2.612379  2.670881  1.444115
# 2023-04-28  1.430940  2.632538  2.708307  1.444532
#
# [2880 rows x 80 columns]

# %%
print("Cumulative Returns:")
for index in Equi_Indi_list:
    print(index, (Equities.C_returns[index][-1] - 1))
# Out:
# Cumulative Returns:
# 005930.KS 4.210194431480378
# KO 2.3876614985128177
# MSFT 12.006320562582793
# NSRGF 2.1475033816513753
# PG 2.8211357029971014
# ^AXJO 0.4989234641164393
# ^FTSE 0.43094019910491643
# ^GDAXI 1.6325381341831817
# ^N225 1.708306719074871
# ^STOXX50E 0.4445324368944088

# %%
Equities.columns
# Out:
# MultiIndex([('Adj Close', '005930.KS'),
#             ('Adj Close',        'KO'),
#             ('Adj Close',      'MSFT'),
#             ('Adj Close',     'NSRGF'),
#             ('Adj Close',        'PG'),
#             ('Adj Close',     '^AXJO'),
#             ('Adj Close',     '^FTSE'),
#             ('Adj Close',    '^GDAXI'),
#             ('Adj Close',     '^N225'),
#             ('Adj Close', '^STOXX50E'),
#             (    'Close', '005930.KS'),
#             (    'Close',        'KO'),
#             (    'Close',      'MSFT'),
#             (    'Close',     'NSRGF'),
#             (    'Close',        'PG'),
#             (    'Close',     '^AXJO'),
#             (    'Close',     '^FTSE'),
#             (    'Close',    '^GDAXI'),
#             (    'Close',     '^N225'),
#             (    'Close', '^STOXX50E'),
#             (     'High', '005930.KS'),
#             (     'High',        'KO'),
#             (     'High',      'MSFT'),
#             (     'High',     'NSRGF'),
#             (     'High',        'PG'),
#             (     'High',     '^AXJO'),
#             (     'High',     '^FTSE'),
#             (     'High',    '^GDAXI'),
#             (     'High',     '^N225'),
#             (     'High', '^STOXX50E'),
#             (      'Low', '005930.KS'),
#             (      'Low',        'KO'),
#             (      'Low',      'MSFT'),
#             (      'Low',     'NSRGF'),
#             (      'Low',        'PG'),
#             (      'Low',     '^AXJO'),
#             (      'Low',     '^FTSE'),
#             (      'Low',    '^GDAXI'),
#             (      'Low',     '^N225'),
#             (      'Low', '^STOXX50E'),
#             (     'Open', '005930.KS'),
#             (     'Open',        'KO'),
#             (     'Open',      'MSFT'),
#             (     'Open',     'NSRGF'),
#             (     'Open',        'PG'),
#             (     'Open',     '^AXJO'),
#             (     'Open',     '^FTSE'),
#             (     'Open',    '^GDAXI'),
#             (     'Open',     '^N225'),
#             (     'Open', '^STOXX50E'),
#             (   'Volume', '005930.KS'),
#             (   'Volume',        'KO'),
#             (   'Volume',      'MSFT'),
#             (   'Volume',     'NSRGF'),
#             (   'Volume',        'PG'),
#             (   'Volume',     '^AXJO'),
#             (   'Volume',     '^FTSE'),
#             (   'Volume',    '^GDAXI'),
#             (   'Volume',     '^N225'),
#             (   'Volume', '^STOXX50E'),
#             ('d_returns', '005930.KS'),
#             ('d_returns',        'KO'),
#             ('d_returns',      'MSFT'),
#             ('d_returns',     'NSRGF'),
#             ('d_returns',        'PG'),
#             ('d_returns',     '^AXJO'),
#             ('d_returns',     '^FTSE'),
#             ('d_returns',    '^GDAXI'),
#             ('d_returns',     '^N225'),
#             ('d_returns', '^STOXX50E'),
#             ('C_returns', '005930.KS'),
#             ('C_returns',        'KO'),
#             ('C_returns',      'MSFT'),
#             ('C_returns',     'NSRGF'),
#             ('C_returns',        'PG'),
#             ('C_returns',     '^AXJO'),
#             ('C_returns',     '^FTSE'),
#             ('C_returns',    '^GDAXI'),
#             ('C_returns',     '^N225'),
#             ('C_returns', '^STOXX50E')],
#            )

# %% [markdown]
# # Maximum DrawDown

# %%
for index in Equi_Indi_list:
    new_column = Equities.loc[:, ('C_returns', index)].cummax() - Equities.loc[:, ('C_returns', index)]
    Equities.insert(loc=len(Equities.columns), column=('Drawdawn', index), value=new_column)
Equities.dropna(inplace=True)

# %%
Equities.head()
# Out:
#                Adj Close                                              \
#                005930.KS         KO       MSFT      NSRGF         PG
# Date
# 2010-01-05  12773.524414  18.707298  23.579987  39.615520  40.938385
# 2010-01-06  13068.775391  18.700653  23.435274  39.409615  40.744221
# 2010-01-07  12633.666992  18.654175  23.191563  38.709557  40.523251
# 2010-01-08  12757.980469  18.308914  23.351496  39.739067  40.469688
# 2010-01-12  12571.507812  18.883247  22.902140  39.739067  40.771004
#
#                                                                               \
#                   ^AXJO        ^FTSE       ^GDAXI         ^N225    ^STOXX50E
# Date
# 2010-01-05  4924.299805  5522.500000  6031.859863  10681.830078  3012.360107
# 2010-01-06  4921.399902  5530.000000  6034.330078  10731.450195  3009.659912
# 2010-01-07  4899.399902  5526.700195  6019.359863  10681.660156  3007.340088
# 2010-01-08  4912.100098  5534.200195  6037.609863  10798.320312  3017.850098
# 2010-01-12  4899.500000  5498.700195  5943.000000  10879.139648  2976.889893
#
#             ...  Drawdawn                                                    \
#             ... 005930.KS        KO      MSFT     NSRGF        PG     ^AXJO
# Date        ...
# 2010-01-05  ...  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2010-01-06  ...  0.000000  0.000351  0.006139  0.005061  0.004744  0.000595
# 2010-01-07  ...  0.034611  0.002805  0.016478  0.022267  0.010144  0.005106
# 2010-01-08  ...  0.024722  0.021038  0.009693  0.000000  0.011453  0.002502
# 2010-01-12  ...  0.039555  0.000000  0.028756  0.000000  0.004090  0.005086
#
#
#                ^FTSE    ^GDAXI     ^N225 ^STOXX50E
# Date
# 2010-01-05  0.000000  0.000000  0.000000  0.000000
# 2010-01-06  0.000000  0.000000  0.000000  0.000895
# 2010-01-07  0.000600  0.002475  0.004673  0.001663
# 2010-01-08  0.000000  0.000000  0.000000  0.000000
# 2010-01-12  0.006454  0.015642  0.000000  0.013573
#
# [5 rows x 90 columns]

# %%
print("Maximum DrawDown:")
for index in Equi_Indi_list:
    print(index, Equities.Drawdawn[index].max())
# Out:
# Maximum DrawDown:
# 005930.KS 2.738271314163393
# KO 1.0611459784389992
# MSFT 5.085631752828547
# NSRGF 0.84624889610541
# PG 0.9135537079923233
# ^AXJO 0.5365748835797182
# ^FTSE 0.5080632145939505
# ^GDAXI 0.8840980460191967
# ^N225 0.7243492395631572
# ^STOXX50E 0.49021135905134494

# %% [markdown]
# * Calculation of annual average returns (CAGR)

# %%
CAGR = {}

for index in Equi_Indi_list:
    equity = index
    prices = Equities.Close[index]
    total_returns = prices[-1] / prices[0]
    years = 13
    C_A_G_R = (pow(total_returns,1/years) - 1) * 100
    CAGR[equity] = C_A_G_R
    print(f"{equity}: {CAGR[equity]}")
# Out:
# 005930.KS: 11.219249592515744
# KO: 6.533730555355133
# MSFT: 19.30801582365298
# NSRGF: 7.823383504211434
# PG: 7.49135128579852
# ^AXJO: 3.0847113801853343
# ^FTSE: 2.7628918114616763
# ^GDAXI: 7.752521397768408
# ^N225: 7.944315133459678
# ^STOXX50E: 2.883798498750023

# %% [markdown]
# # Volatility: Standard Deviation

# %% [markdown]
# * calculation of annualized standard deviation

# %%
STD = {}
Volatility = {}
d_returns = []
print("Standard Deviation")
for index in Equi_Indi_list:
    equity = index
    prices = Equities.Close[index]
    d_returns = prices.pct_change()
    std = d_returns.std()
    annualized_std = std*pow(252, 0.5)
    STD[equity] = annualized_std*100
    Volatility[equity] = std
    print(f"{equity}: {Volatility[equity] * 100}%")
# new_list = list(filter(lambda x: x<=0, d_returns))
# new_list = list(filter(lambda x: x <= 0, d_returns))
# Out:
# Standard Deviation
# 005930.KS: 1.7748505978664428%
# 28.174879777493484
# KO: 1.1793407981022868%
# 18.721454776626516
# MSFT: 1.7494527786635263%
# 27.7717018967677
# NSRGF: 1.279940729046971%
# 20.31842917176595
# PG: 1.1934721240717503%
# 18.94578262189125
# ^AXJO: 1.0398299265154332%
# 16.506788348174425
# ^FTSE: 1.0883702203760603%
# 17.277341624901716
# ^GDAXI: 1.3539086372343205%
# 21.49263331214626
# ^N225: 1.415066003928987%
# 22.463476410828292
# ^STOXX50E: 1.404351742368975%
# 22.29339278141135

# %% [markdown]
# * risk free rates

# %%
risk_free_rates = {
    'MSFT': 3.46,            # Risk-free rate for Microsoft (USA govt bond's interest rate)
    '005930.KS': 3.32,       # Risk-free rate for Samsung Electronics (South Korea govt bond's interest rate)
    'PG': 3.32,             # Risk-free rate for Procter & Gamble (USA govt bond's interest rate)
    'NSRGF': 2.25 ,          # Risk-free rate for Nestle (Sweden govt bond's interest rate)
    'KO': 3.46,            # Risk-free rate for Coca-Cola (USA govt bond's interest rate)
    '^AXJO': 2,
    '^FTSE':2,
    '^GDAXI': 2,
    '^N225' : 2,
    '^STOXX50E':2
}

# %% [markdown]
# # Sharpe Ratio

# %%
Sharpe_Ratio = {}
for index in Equi_Indi_list:
    equity = index
    Sharpe_Ratio[equity] = (CAGR[index] - risk_free_rates[index])/(STD[index])
    print(f"{equity}: {Sharpe_Ratio[equity]}")
# Out:
# 005930.KS: 0.2803649795455661
# KO: 0.16418224929788278
# MSFT: 0.570653389646873
# NSRGF: 0.27430188904347425
# PG: 0.22017307857098795
# ^AXJO: 0.06571304831113912
# ^FTSE: 0.044155624633949786
# ^GDAXI: 0.26765084176620885
# ^N225: 0.2646213357516774
# ^STOXX50E: 0.03964396569942243

# %% [markdown]
# # Sortino Ratio

# %%
STD_neg_earnings = {}
Volatility = {}
d_returns = []
print("Standard Deviation of negative earnings")
for index in Equi_Indi_list:
    equity = index
    prices = Equities.Close[index]
    d_returns = prices.pct_change()
    neg_d_returns = list(filter(lambda x: x<=0 , d_returns))
    std_neg_earning = np.std(neg_d_returns)
    annualized_std_neg_earning = std_neg_earning*pow(252, 0.5)
    STD_neg_earnings[equity] = annualized_std_neg_earning*100
    Volatility[equity] = std_neg_earning
    print(f"{equity}: {Volatility[equity] * 100}%")
# Out:
# Standard Deviation
# 005930.KS: 1.1042958195142187%
# KO: 0.9499353042345421%
# MSFT: 1.2528686683014871%
# NSRGF: 0.8951882002374949%
# PG: 0.9198583984843124%
# ^AXJO: 0.8251277874662485%
# ^FTSE: 0.8454456634879001%
# ^GDAXI: 1.046841139708179%
# ^N225: 1.0763205778102458%
# ^STOXX50E: 1.084361812719843%

# %%
Sortino_Ratio = {}
for index in Equi_Indi_list:
    equity = index
    Sortino_Ratio[equity] = (CAGR[index] - risk_free_rates[index])/STD_neg_earnings[index]
    print(f"{equity}: {Sortino_Ratio[equity]}")
# Out:
# 005930.KS: 0.45060928672731787
# KO: 0.2038315915389819
# MSFT: 0.7968362394479213
# NSRGF: 0.39219703716840887
# PG: 0.2856640023926626
# ^AXJO: 0.08281189318117822
# ^FTSE: 0.0568429988929529
# ^GDAXI: 0.34616024598662926
# ^N225: 0.34790439192224865
# ^STOXX50E: 0.05134270835742147
